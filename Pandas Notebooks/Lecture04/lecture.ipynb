# %%
import pandas as pd

# %%
df = pd.read_csv("unclean_data.csv")

# %%
df.head()
# Out:
#   Employee_ID             Name   Age  Gender       City      Department  \
# 0     EMP0001     Aarav Sharma  28.0  Female  Hyderabad              HR
# 1     EMP0002     Vivaan Verma  56.0  Female  Hyderabad  Data Analytics
# 2     EMP0003    Aditya Singh   42.0  Female     Mumbai      Operations
# 3     EMP0004      Arjun Mehta   NaN  Female   Amritsar              HR
# 4     EMP0005      Rohan Gupta  44.0  Female  Hyderabad              IT
#
#      Salary Experience_Years         Joining_Date    Education  \
# 0   31556.0              5.0  2026-04-26 00:00:00     Graduate
# 1   77124.0             19.0  2026-01-11 00:00:00      Diploma
# 2   51793.0             12.0  2019-01-15 00:00:00  High School
# 3  101854.0              3.0  2025-01-18 00:00:00     Graduate
# 4   67638.0              3.0  2022-02-25 00:00:00  High School
#
#   Employment_Type Employment_Status   Product Quantity Sales_Amount  \
# 0       Full-time          Resigned    Laptop        1       6240.0
# ...

# %%
df.shape[0]
# Out:
# 200

# %%
df.isnull().sum()
# Out:
# Employee_ID           0
# Name                  1
# Age                   3
# Gender                1
# City                  3
# Department            2
# Salary                2
# Experience_Years      1
# Joining_Date          1
# Education             2
# Employment_Type       1
# Employment_Status     1
# Product               1
# Quantity              0
# Sales_Amount          1
# Discount_Percent      1
# Remote_Work           2
# Performance_Rating    1
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Employee_ID           0.0
# Name                  0.5
# Age                   1.5
# Gender                0.5
# City                  1.5
# Department            1.0
# Salary                1.0
# Experience_Years      0.5
# Joining_Date          0.5
# Education             1.0
# Employment_Type       0.5
# Employment_Status     0.5
# Product               0.5
# Quantity              0.0
# Sales_Amount          0.5
# Discount_Percent      0.5
# Remote_Work           1.0
# Performance_Rating    0.5
# dtype: float64

# %%
df.dtypes
# Out:
# Employee_ID           str
# Name                  str
# Age                   str
# Gender                str
# City                  str
# Department            str
# Salary                str
# Experience_Years      str
# Joining_Date          str
# Education             str
# Employment_Type       str
# Employment_Status     str
# Product               str
# Quantity              str
# Sales_Amount          str
# Discount_Percent      str
# Remote_Work           str
# Performance_Rating    str
# dtype: object

# %%
df.notnull().sum()
# Out:
# Employee_ID           200
# Name                  199
# Age                   197
# Gender                199
# City                  197
# Department            198
# Salary                198
# Experience_Years      199
# Joining_Date          199
# Education             198
# Employment_Type       199
# Employment_Status     199
# Product               199
# Quantity              200
# Sales_Amount          199
# Discount_Percent      199
# Remote_Work           198
# Performance_Rating    199
# dtype: int64

# %%
df.head()
# Out:
#   Employee_ID             Name   Age  Gender       City      Department  \
# 0     EMP0001     Aarav Sharma  28.0  Female  Hyderabad              HR
# 1     EMP0002     Vivaan Verma  56.0  Female  Hyderabad  Data Analytics
# 2     EMP0003    Aditya Singh   42.0  Female     Mumbai      Operations
# 3     EMP0004      Arjun Mehta   NaN  Female   Amritsar              HR
# 4     EMP0005      Rohan Gupta  44.0  Female  Hyderabad              IT
#
#      Salary Experience_Years         Joining_Date    Education  \
# 0   31556.0              5.0  2026-04-26 00:00:00     Graduate
# 1   77124.0             19.0  2026-01-11 00:00:00      Diploma
# 2   51793.0             12.0  2019-01-15 00:00:00  High School
# 3  101854.0              3.0  2025-01-18 00:00:00     Graduate
# 4   67638.0              3.0  2022-02-25 00:00:00  High School
#
#   Employment_Type Employment_Status   Product Quantity Sales_Amount  \
# 0       Full-time          Resigned    Laptop        1       6240.0
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Name, Age, Gender, City, Department, Salary, Experience_Years, Joining_Date, Education, Employment_Type, Employment_Status, Product, Quantity, Sales_Amount, Discount_Percent, Remote_Work, Performance_Rating]
# Index: []

# %% [markdown]
# # Employee ID

# %%
df[df['Employee_ID'].duplicated(keep=False)]
# Out:
#    Employee_ID                  Name   Age  Gender       City      Department  \
# 5      EMP0006          Rahul Kapoor  24.0  Female    KOLKATA              IT
# 10     EMP0006           Rajiv Sethi  26.0    Male  Bangalore  Data Analytics
# 49     EMP0050        Charles Taylor  25.0    Male  Bangalore         Finance
# 50     EMP0050  Christopher Anderson  49.0  Female    Chennai           Sales
#
#       Salary Experience_Years         Joining_Date      Education  \
# 5    85043.0              3.0  2018-05-12 00:00:00  Post Graduate
# 10  152399.0             18.0  2018-10-11 00:00:00  Post Graduate
# 49  176262.0             19.0  2025-01-22 00:00:00        Diploma
# 50  141056.0             20.0  2021-05-02 00:00:00       Graduate
#
#    Employment_Type Employment_Status   Product Quantity Sales_Amount  \
# 5         Contract          Inactive  Keyboard        8      26028.0
# 10        Contract          Resigned     Phone        9      49597.0
# ...

# %%
df = df[df['Employee_ID']!='EMP0006']

# %%
df.shape
# Out:
# (198, 18)

# %%
df = df[df['Employee_ID']!='EMP0050']

# %%
len(df['Employee_ID'].unique())
# Out:
# 196

# %% [markdown]
# # Name

# %%
df[df['Name'].isnull()]
# Out:
#     Employee_ID Name   Age  Gender       City        Department    Salary  \
# 128     EMP0129  NaN  22.0  Female  Bangalore  Customer Support  140615.0
#
#     Experience_Years         Joining_Date Education Employment_Type  \
# 128              7.0  2021-07-08 00:00:00      12th          Intern
#
#     Employment_Status   Product Quantity Sales_Amount Discount_Percent  \
# 128            Active  Keyboard        3      34092.0             13.0
#
#     Remote_Work Performance_Rating
# 128          No               Poor

# %%
df.dropna(subset=['Name'],inplace=True)

# %% [markdown]
# # Age

# %%
df['Age'].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
df['Age'].value_counts()
# Out:
# Age
# 36.0      10
# 55.0      10
# 26.0      10
# 28.0       8
# 56.0       8
# 35.0       8
# 53.0       8
# 42.0       7
# 50.0       7
# 31.0       7
# 57.0       7
# 27.0       7
# 24.0       6
# 49.0       6
# 44.0       5
# 37.0       5
# 47.0       5
# 46.0       5
# 25.0       4
# 33.0       4
# 22.0       4
# 40.0       4
# 51.0       4
# 52.0       4
# 48.0       4
# 38.0       4
# 30.0       3
# 32.0       3
# 45.0       3
# 23.0       3
# 41.0       3
# 39.0       3
# 29.0       2
# 58.0       2
# 43.0       2
# 54.0       2
# 34.0       2
# thirty     1
# 5          1
# 92         1
# Name: count, dtype: int64

# %%
df['Age'] = df['Age'].replace("thity","30.0")

# %%
df['Age'] = pd.to_numeric(df['Age'],errors='coerce')

# %%
df['Age'].isnull().sum()
# Out:
# 4

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Gender

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      98
# Female    91
# M          1
# F          1
# male       1
# female     1
# ?          1
# Name: count, dtype: int64

# %%
df['Gender'] = df['Gender'].str.lower()

# %%
gender_map = {
    "male":"m",
    "female":"f",
    "?":"m"
}

# %%
df['Gender'] = df['Gender'].map(gender_map)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# m    100
# f     92
# Name: count, dtype: int64

# %%
df['Gender'].isnull().sum()
# Out:
# 3

# %%
df['Gender'] = df['Gender'].ffill()

# %% [markdown]
# # City

# %%
df['City'].value_counts()
# Out:
# City
# Mumbai       28
# Jaipur       21
# Chennai      21
# Pune         20
# Hyderabad    19
# Delhi        18
# Bangalore    18
# Amritsar     15
# Ahmedabad    14
# Kolkata      13
# MUMBAI        2
# JAIPUR        2
# BANGALORE     1
# Name: count, dtype: int64

# %%
df['City'] = df['City'].str.lower().str.strip()

# %%
df['City'] = df['City'].fillna(df['City'].mode()[0])

# %%
df['City'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Department

# %%
df['Department'] = df['Department'].str.lower().str.strip()

# %%
df['Department'].isnull().sum()
# Out:
# 2

# %%
df['Department'] = df['Department'].fillna(df['Department'].mode()[0])

# %%
df.shape[0]
# Out:
# 195

# %%
df[df['Department'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Name, Age, Gender, City, Department, Salary, Experience_Years, Joining_Date, Education, Employment_Type, Employment_Status, Product, Quantity, Sales_Amount, Discount_Percent, Remote_Work, Performance_Rating]
# Index: []

# %%
df['Department'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Salary

# %%
df['Salary'] = pd.to_numeric(df['Salary'],errors='coerce')

# %%
df['Salary'].isnull().sum()
# Out:
# 5

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Gender', 'City', 'Department', 'Salary',
#        'Experience_Years', 'Joining_Date', 'Education', 'Employment_Type',
#        'Employment_Status', 'Product', 'Quantity', 'Sales_Amount',
#        'Discount_Percent', 'Remote_Work', 'Performance_Rating'],
#       dtype='str')

# %% [markdown]
# # Experience Years

# %%
df['Experience_Years'].value_counts()
# Out:
# Experience_Years
# 12.0       13
# 16.0       13
# 8.0        13
# 5.0        12
# 3.0        12
# 10.0       12
# 15.0       12
# 20.0       12
# 14.0       11
# 18.0       10
# 9.0         9
# 19.0        8
# 13.0        8
# 11.0        8
# 4.0         8
# 1.0         8
# 2.0         8
# 6.0         8
# 17.0        6
# 7.0         2
# 5 years     1
# Name: count, dtype: int64

# %%
df['Experience_Years'] = pd.to_numeric(df['Experience_Years'],errors='coerce')

# %%
df['Experience_Years'].value_counts()
# Out:
# Experience_Years
# 12.0    13
# 16.0    13
# 8.0     13
# 5.0     12
# 3.0     12
# 10.0    12
# 15.0    12
# 20.0    12
# 14.0    11
# 18.0    10
# 9.0      9
# 19.0     8
# 13.0     8
# 11.0     8
# 4.0      8
# 1.0      8
# 2.0      8
# 6.0      8
# 17.0     6
# 7.0      2
# Name: count, dtype: int64

# %%
df['Experience_Years'] = df['Experience_Years'].fillna(df['Experience_Years'].median())

# %%
df.isnull().sum()
# Out:
# Employee_ID           0
# Name                  0
# Age                   0
# Gender                0
# City                  0
# Department            0
# Salary                0
# Experience_Years      0
# Joining_Date          1
# Education             2
# Employment_Type       1
# Employment_Status     1
# Product               1
# Quantity              0
# Sales_Amount          1
# Discount_Percent      1
# Remote_Work           2
# Performance_Rating    1
# dtype: int64

# %% [markdown]
# # Joining Date

# %%
df[df['Joining_Date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Name, Age, Gender, City, Department, Salary, Experience_Years, Joining_Date, Education, Employment_Type, Employment_Status, Product, Quantity, Sales_Amount, Discount_Percent, Remote_Work, Performance_Rating]
# Index: []

# %%
df.dropna(subset=['Joining_Date'],inplace=True)

# %%
df['Joining_Date'].value_counts()
# Out:
# Joining_Date
# 2025-05-05 00:00:00    3
# 2020-07-26 00:00:00    2
# 2021-06-20 00:00:00    2
# 2019-07-10 00:00:00    2
# 2023-07-26 00:00:00    2
#                       ..
# 2025-03-08 00:00:00    1
# 2018-08-26 00:00:00    1
# 2021-11-21 00:00:00    1
# 2018-06-30 00:00:00    1
# 2026-01-29 00:00:00    1
# Name: count, Length: 187, dtype: int64

# %%
df['Joining_Date'].dtype
# Out:
# dtype('<M8[us]')

# %%
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'],errors='coerce')

# %%
df[df['Joining_Date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Name, Age, Gender, City, Department, Salary, Experience_Years, Joining_Date, Education, Employment_Type, Employment_Status, Product, Quantity, Sales_Amount, Discount_Percent, Remote_Work, Performance_Rating]
# Index: []

# %%
df['Joining_Date'] = df['Joining_Date'].fillna(df['Joining_Date'].mode()[0])

# %%
df['Joining_Year'] = df['Joining_Date'].dt.year

# %%
df['Joining_month'] = df['Joining_Date'].dt.month

# %%
df['Joining_day'] = df['Joining_Date'].dt.day

# %%
df.head()
# Out:
#   Employee_ID             Name   Age Gender       City      Department  \
# 0     EMP0001     Aarav Sharma  28.0      f  hyderabad              hr
# 1     EMP0002     Vivaan Verma  56.0      f  hyderabad  data analytics
# 2     EMP0003    Aditya Singh   42.0      f     mumbai      operations
# 3     EMP0004      Arjun Mehta  40.0      f   amritsar              hr
# 4     EMP0005      Rohan Gupta  44.0      f  hyderabad              it
#
#      Salary  Experience_Years    Education Employment_Type Employment_Status  \
# 0   31556.0               5.0     Graduate       Full-time          Resigned
# 1   77124.0              19.0      Diploma       Full-time          Inactive
# 2   51793.0              12.0  High School        Contract            Active
# 3  101854.0               3.0     Graduate       Part-time          On Leave
# 4   67638.0               3.0  High School       Part-time          Inactive
#
#     Product Quantity Sales_Amount Discount_Percent Remote_Work  \
# ...

# %%
df.drop(columns=['Joining_Date'],inplace=True)

# %% [markdown]
# # Education

# %%
df['Education'] = df['Education'].str.lower().str.strip()

# %%
df['Education'].isnull().sum()
# Out:
# 0

# %%
df['Education'] = df['Education'].fillna(df['Education'].mode()[0])

# %%
df['Education'].value_counts()
# Out:
# Education
# 12th             47
# high school      38
# post graduate    38
# graduate         37
# diploma          34
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Gender', 'City', 'Department', 'Salary',
#        'Experience_Years', 'Education', 'Employment_Type', 'Employment_Status',
#        'Product', 'Quantity', 'Sales_Amount', 'Discount_Percent',
#        'Remote_Work', 'Performance_Rating', 'Joining_Year', 'Joining_month',
#        'Joining_day', 'Educatoin'],
#       dtype='str')

# %% [markdown]
# # Employment Type

# %%
df['Employment_Type'] = df['Employment_Type'].str.lower().str.strip()

# %%
df['Employment_Type'].isnull().sum()
# Out:
# 1

# %%
df['Employment_Type'] = df['Employment_Type'].fillna(df['Employment_Type'].mode()[0])

# %%
df['Employment_Type'].value_counts()
# Out:
# Employment_Type
# part-time    56
# contract     50
# full-time    45
# intern       43
# Name: count, dtype: int64

# %% [markdown]
# # Employment Status

# %%
df['Employment_Status'] = df['Employment_Status'].str.lower().str.strip()

# %%
df['Employment_Status'].isnull().sum()
# Out:
# 0

# %%
df['Employment_Status'] = df['Employment_Status'].fillna(df['Employment_Status'].mode()[0])

# %%
df['Employment_Status'].value_counts()
# Out:
# Employment_Status
# resigned    54
# on leave    49
# active      46
# inactive    45
# Name: count, dtype: int64

# %% [markdown]
# # Product

# %%
df['Product'] = df['Product'].str.lower().str.strip()

# %%
df['Product'].isnull().sum()
# Out:
# 0

# %%
df['Product'] = df['Product'].fillna(df['Product'].mode()[0])

# %%
df['Product'].value_counts()
# Out:
# Product
# software license    36
# laptop              31
# keyboard            28
# headphones          27
# tablet              25
# phone               24
# monitor             23
# Name: count, dtype: int64

# %%
df['Product'] = df['Product'].replace("not available",df['Product'].mode()[0])

# %% [markdown]
# # Quantity

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'],errors='coerce')

# %%
df['Quantity'].isnull().sum()
# Out:
# 0

# %%
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].median())

# %%
df.head()
# Out:
#   Employee_ID             Name   Age Gender       City      Department  \
# 0     EMP0001     Aarav Sharma  28.0      f  hyderabad              hr
# 1     EMP0002     Vivaan Verma  56.0      f  hyderabad  data analytics
# 2     EMP0003    Aditya Singh   42.0      f     mumbai      operations
# 3     EMP0004      Arjun Mehta  40.0      f   amritsar              hr
# 4     EMP0005      Rohan Gupta  44.0      f  hyderabad              it
#
#      Salary  Experience_Years    Education Employment_Type Employment_Status  \
# 0   31556.0               5.0     graduate       full-time          resigned
# 1   77124.0              19.0      diploma       full-time          inactive
# 2   51793.0              12.0  high school        contract            active
# 3  101854.0               3.0     graduate       part-time          on leave
# 4   67638.0               3.0  high school       part-time          inactive
#
#     Product  Quantity Sales_Amount Discount_Percent Remote_Work  \
# ...

# %% [markdown]
# # Sales Amount

# %%
df['Sales_Amount'] = pd.to_numeric(df['Sales_Amount'],errors='coerce')

# %%
df['Sales_Amount'].isnull().sum()
# Out:
# 0

# %%
df['Sales_Amount'] = df['Sales_Amount'].fillna(df['Sales_Amount'].median())

# %% [markdown]
# # Discount Percent

# %%
df['Discount_Percent'] = pd.to_numeric(df['Discount_Percent'],errors='coerce')

# %%
df['Discount_Percent'].isnull().sum()
# Out:
# 0

# %%
df['Discount_Percent'] = df['Discount_Percent'].fillna(df['Discount_Percent'].median())

# %%
df['Discount_Percent'] = df['Discount_Percent'].where(df['Discount_Percent']>=0,0)

# %% [markdown]
# # Remote Work

# %%
df['Remote_Work'] = df['Remote_Work'].str.strip().str.lower()

# %%
df['Remote_Work'].value_counts()
# Out:
# Remote_Work
# no     113
# yes     79
# Name: count, dtype: int64

# %%
df['Remote_Work'] = df['Remote_Work'].replace({'y':"yes","n":"no"})

# %%
df['Remote_Work'].isnull().sum()
# Out:
# 0

# %%
df['Remote_Work'] = df['Remote_Work'].fillna(df['Remote_Work'].mode()[0])

# %%
df.head()
# Out:
#   Employee_ID             Name   Age Gender       City      Department  \
# 0     EMP0001     Aarav Sharma  28.0      f  hyderabad              hr
# 1     EMP0002     Vivaan Verma  56.0      f  hyderabad  data analytics
# 2     EMP0003    Aditya Singh   42.0      f     mumbai      operations
# 3     EMP0004      Arjun Mehta  40.0      f   amritsar              hr
# 4     EMP0005      Rohan Gupta  44.0      f  hyderabad              it
#
#      Salary  Experience_Years    Education Employment_Type Employment_Status  \
# 0   31556.0               5.0     graduate       full-time          resigned
# 1   77124.0              19.0      diploma       full-time          inactive
# 2   51793.0              12.0  high school        contract            active
# 3  101854.0               3.0     graduate       part-time          on leave
# 4   67638.0               3.0  high school       part-time          inactive
#
#     Product  Quantity  Sales_Amount  Discount_Percent Remote_Work  \
# ...

# %% [markdown]
# # Performance Rating

# %%
df['Performance_Rating'] = df['Performance_Rating'].str.strip().str.lower()

# %%
df['Performance_Rating'] = df['Performance_Rating'].replace("unknown",df['Performance_Rating'].mode()[0])

# %%
df['Performance_Rating'] = df['Performance_Rating'].fillna(df['Performance_Rating'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Employee_ID           0
# Name                  0
# Age                   0
# Gender                0
# City                  0
# Department            0
# Salary                0
# Experience_Years      0
# Education             0
# Employment_Type       0
# Employment_Status     0
# Product               0
# Quantity              0
# Sales_Amount          0
# Discount_Percent      0
# Remote_Work           0
# Performance_Rating    0
# Joining_Year          0
# Joining_month         0
# Joining_day           0
# dtype: int64

# %%
df.head(20)
# Out:
#    Employee_ID              Name   Age Gender       City        Department  \
# 0      EMP0001      Aarav Sharma  28.0      f  hyderabad                hr
# 1      EMP0002      Vivaan Verma  56.0      f  hyderabad    data analytics
# 2      EMP0003     Aditya Singh   42.0      f     mumbai        operations
# 3      EMP0004       Arjun Mehta  40.0      f   amritsar                hr
# 4      EMP0005       Rohan Gupta  44.0      f  hyderabad                it
# 6      EMP0007    Karan Malhotra  29.0      f   amritsar  customer support
# 7      EMP0008     Vikram Bhatia  30.0      f     mumbai         marketing
# 8      EMP0009       Ankit Arora  28.0      f     jaipur             sales
# 9      EMP0010     Nikhil Khanna  44.0      m   amritsar        operations
# 11     EMP0012    Siddharth Jain  44.0      f     mumbai                hr
# 12     EMP0013    Manish Agarwal  25.0      m      delhi        operations
# ...

# %%
df.to_csv("clean_data.csv",index=False)
