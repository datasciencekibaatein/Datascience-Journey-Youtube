# %%
lst = [119, 142,  76, 143, 146, 191,  60, 140, 163,  89, 142,  20,  74,
         1, 163, 188, 142, 164, 186, 196,  26, 168,  23,  12,  24,  85,
         8, 142, 180, 115,  87,  28,  80,  -5, 198,  27,  -8, 186,  64,
        -6, 143,  74,  51,   8,  41,  20, 167, 193,  10,  20,   1, 144,
       111,  -3,   8,  37,  31,  -8, 151, 143, 171,  70, 197, 165, 196,
        -2,  70,  18,  26,  -5, 143,  40,  -8,  22,  32,  30,  97,  48,
        78,  47, 102, 173,   2,  28, 153,  68,  55,  90, 128, 175,  24,
        91, 123, 165, 149, 149,   5, 144, 124,   0]

# %%
import numpy as np

# %% [markdown]
# # Indexing 1d & 2D

# %%
arr = np.array([45,67,90,23,13,345,23])

# %%
arr[2]
# Out:
# 90

# %%
matrix = np.array([
    [3,4,2],
    [4,6,2],
    [4,3,7]
])

# %% [markdown]
# [
#     [00,01,02],
#     [10,11,12],
#     [20,21,22]
# ]

# %%
matrix[1][1]
# Out:
# 6

# %%
matrix[1][1]
# Out:
# 6

# %%
matrix[0][1]
# Out:
# 4

# %% [markdown]
# # Slicing

# %%
arr
# Out:
# array([ 45,  67,  90,  23,  13, 345,  23])

# %%
arr[3:7]
# Out:
# array([ 23,  13, 345,  23])

# %%
matrix
# Out:
# array([[3, 4, 2],
#        [4, 6, 2],
#        [4, 3, 7]])

# %%
matrix[1:3,1:3]
# Out:
# array([[6, 2],
#        [3, 7]])

# %%
arr
# Out:
# array([ 45,  67,  90,  23,  13, 345,  23])

# %%
arr[4:]
# Out:
# array([ 13, 345,  23])

# %%
matrix
# Out:
# array([[3, 4, 2],
#        [4, 6, 2],
#        [4, 3, 7]])

# %%
matrix[1:,1:]
# Out:
# array([[6, 2],
#        [3, 7]])

# %%
temp = np.array(lst)

# %% [markdown]
# # Boolean Filtering

# %%
arr
# Out:
# array([ 45,  67,  90,  23,  13, 345,  23])

# %%
arr[arr<40]
# Out:
# array([23, 13, 23])

# %%
print(temp[temp<=100])
# Out:
# [76 60 89 20 74  1 26 23 12 24 85  8 87 28 80 -5 27 -8 64 -6 74 51  8 41
#  20 10 20  1 -3  8 37 31 -8 70 -2 70 18 26 -5 40 -8 22 32 30 97 48 78 47
#   2 28 68 55 90 24 91  5  0]

# %% [markdown]
# >= 100 and <=1

# %%
temp[(temp<=100) & (temp>=1)]
# Out:
# array([76, 60, 89, 20, 74,  1, 26, 23, 12, 24, 85,  8, 87, 28, 80, 27, 64,
#        74, 51,  8, 41, 20, 10, 20,  1,  8, 37, 31, 70, 70, 18, 26, 40, 22,
#        32, 30, 97, 48, 78, 47,  2, 28, 68, 55, 90, 24, 91,  5])

# %%
temp[(temp<=100) | (temp>=1)]
# Out:
# array([119, 142,  76, 143, 146, 191,  60, 140, 163,  89, 142,  20,  74,
#          1, 163, 188, 142, 164, 186, 196,  26, 168,  23,  12,  24,  85,
#          8, 142, 180, 115,  87,  28,  80,  -5, 198,  27,  -8, 186,  64,
#         -6, 143,  74,  51,   8,  41,  20, 167, 193,  10,  20,   1, 144,
#        111,  -3,   8,  37,  31,  -8, 151, 143, 171,  70, 197, 165, 196,
#         -2,  70,  18,  26,  -5, 143,  40,  -8,  22,  32,  30,  97,  48,
#         78,  47, 102, 173,   2,  28, 153,  68,  55,  90, 128, 175,  24,
#         91, 123, 165, 149, 149,   5, 144, 124,   0])

# %% [markdown]
# # Fancy Indexing

# %%
arr
# Out:
# array([ 45,  67,  90,  23,  13, 345,  23])

# %%
arr[[0,3,5]]
# Out:
# array([ 45,  23, 345])

# %%
arr[[True,False,True,False,True,False,True]]
# Out:
# array([45, 90, 13, 23])

# %%
arr>=70
# Out:
# array([False, False,  True, False, False,  True, False])

# %%
arr[[False, False,  True, False, False,  True, False]]
# Out:
# array([ 90, 345])

# %% [markdown]
# # Modifying values

# %% [markdown]
# Squashing

# %%
temp[temp<0] = 0

# %%
temp[temp>100] = 100

# %%
temp[(temp<0) | (temp>100)]
# Out:
# array([], dtype=int64)
