# %%
from mathTool import basic

# %%
basic.add(34,23)
# Out:
# 57

# %%
from mathTool.basic import multiply,divide

print(multiply(34,2))
print(divide(34,0))
# Out:
# 68
# division by zero

# %%
from mathTool.advanced.trigonometry import sin_function

sin_function(23)
# Out:
# 'this the sin function'
