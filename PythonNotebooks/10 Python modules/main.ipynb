# %% [markdown]
# - Reusability
# - Organisation
# - Maintainability
# - Namespace separation

# %%
import calculator

# %%
calculator.multiply(34,3)
# Out:
# 102

# %%
calculator.divide(12,0)
# Out:
# ZeroDivisionError('division by zero')

# %%
calculator.add(34,78,45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 calculator.add(34,78,45)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
import addition

addition.add(67,45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import addition
# ----> 3 addition.add(67,45)
#
# TypeError: add() missing 1 required positional argument: 'c'

# %% [markdown]
# ### Types of module
#
# 1. Built-in module(math,datetime,sys,random,os,json)
# 2. User-defined
# 3. Third party module

# %% [markdown]
# ### Different ways to import module

# %%
import calculator

print(calculator.add(45,23))
print(calculator.subtract(34,12))
print(calculator.multiply(23,12))
# Out:
# 68
# 22
# 276

# %% [markdown]
# import module with alias

# %%
import calculator as calc


print(calc.add(67,23))
print(calc.subtract(12,10))
# Out:
# 90
# 2

# %%
from calculator import add

print(add(34,67))
# Out:
# 101

# %%
from calculator import add,subtract

print(add(78,90))
print(subtract(78,23))
# Out:
# 168
# 55

# %%
from calculator import subtract as sub
print(sub(34,23))
# Out:
# 11

# %%
from calculator import *

print(multiply(34,12))
print(pi)
# Out:
# 408
# 3.1459

# %% [markdown]
# dir() - What's inside a module ?

# %%
dir(calculator)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add',
#  'divide',
#  'multiply',
#  'pi',
#  'subtract']

# %%
help(calculator)
# Out:
# Help on module calculator:
#
# NAME
#     calculator - This the calculator module
#
# FUNCTIONS
#     add(a, b)
#
#     divide(a, b)
#
#     multiply(a, b)
#
#     subtract(a, b)
#
# DATA
#     pi = 3.1459
#
# FILE
#     /Users/dhruv/Downloads/PythonModules/calculator.py

# %%
print(calculator.__name__)
# Out:
# calculator

# %%
print(calculator.__file__)
# Out:
# /Users/dhruv/Downloads/PythonModules/calculator.py

# %% [markdown]
# # Math module - in built module

# %%
import math

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
#     ceil(x, /)
# ...

# %%
math.pi
# Out:
# 3.141592653589793

# %%
from math import pow

print(pow(3,7))
# Out:
# 2187.0

# %%
math.e
# Out:
# 2.718281828459045

# %%
print(math.sqrt(25))
print(math.ceil(4.3))
print(math.floor(4.9))
print(math.factorial(5))
print(math.gcd(12,18))
print(math.fabs(-7))
print(math.isqrt(17))
# Out:
# 5.0
# 5
# 4
# 120
# 6
# 7.0
# 4

# %%
math.radians(180)
# Out:
# 3.141592653589793

# %%
math.degrees(math.pi)
# Out:
# 180.0

# %%
math.sin(math.radians(45))
# Out:
# 0.7071067811865475

# %%
math.cos(math.radians(0))
# Out:
# 1.0

# %%
radius = 5

print(math.pi * math.pow(radius,2) )
# Out:
# 78.53981633974483

# %% [markdown]
# # Datetime module

# %%
import datetime

# %% [markdown]
# This module handles dates,times and arithmetic between them, it contains four main classes: date,time,datetime, and timedelta

# %%
help(datetime)
# Out:
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# CLASSES
#     builtins.object
#         date
#             datetime
#         time
#         timedelta
#         tzinfo
#             timezone
#
#     class date(builtins.object)
#      |  date(year, month, day) --> date object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __format__(...)
#      |      Formats self with strftime.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
# ...

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 7, 2, 1, 15, 14, 62065)

# %%
datetime.date.today()
# Out:
# datetime.date(2026, 7, 2)

# %%
type(datetime.date(2000,12,10))
# Out:
# datetime.date

# %% [markdown]
# Formatting date as text

# %%
now = datetime.datetime.now()

print(now.strftime("%d-%m-%y"))
print(now.strftime("%A, %d %B %Y %H:%M %p"))
# Out:
# 02-07-26
# Thursday, 02 July 2026 01:21 AM

# %% [markdown]
# %Y (4 digit year), %m(month number) ,%d(day), %A (weekday name) ,%B(month name) ,%H(24 hour),%I(12 hour),%M(minute), %p(AM?PM)

# %%
today = datetime.date.today()

one_week_later = today + datetime.timedelta(days=7)

print(one_week_later)
# Out:
# 2026-07-09
